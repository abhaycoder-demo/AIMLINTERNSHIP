# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Create CNN model
model = keras.Sequential()

# First Convolution Layer
model.add(Conv2D(
    filters=32,
    kernel_size=(3, 3),
    strides=(1, 1),
    padding='same',
    activation='relu',
    input_shape=(32, 32, 3)
))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Second Convolution Layer
model.add(Conv2D(
    filters=64,
    kernel_size=(3, 3),
    strides=(1, 1),
    padding='same',
    activation='relu'
))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Fully Connected Layers
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(10, activation='softmax'))

# Model Summary
model.summary()
# Out:
# c:\Users\biren\OneDrive\Desktop\aiml intenship\aiml\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
import ultralytics as ut
from ultralytics import YOLO

# %%
model = YOLO('yolo11n.pt')

# %%
import cv2
print(cv2.__version__)
from ultralytics import YOLO
model= YOLO('yolo11n.pt')
predict_class=[0,14]
img='./mchild.jpg'

pred=model(img,classes=predict_class,conf=.4)
pred_img=pred[0].plot()
cv2.imshow('predicted image',pred_img)
cv2.waitKey(5000)
cv2.destroyAllWindows()
# Out:
# 4.10.0
#
# image 1/1 c:\Users\biren\OneDrive\Desktop\aiml intenship\mchild.jpg: 448x640 2 persons, 1539.3ms
# Speed: 60.0ms preprocess, 1539.3ms inference, 27.7ms postprocess per image at shape (1, 3, 448, 640)

# %%
import cv2
print(cv2.__version__)
from ultralytics import YOLO
model= YOLO('yolo11n.pt')
predict_class=[0,14]
img='car.jpg'

pred=model(img,classes=predict_class,conf=.4)
pred_img=pred[0].plot()
cv2.imshow('predicted image',pred_img)
cv2.waitKey(5000)
cv2.destroyAllWindows()
# Out:
# 4.10.0
#
# image 1/1 c:\Users\biren\OneDrive\Desktop\aiml intenship\car.jpg: 640x640 (no detections), 1020.8ms
# Speed: 98.8ms preprocess, 1020.8ms inference, 26.8ms postprocess per image at shape (1, 3, 640, 640)

# %%
text = """Artificial Intelligence (AI) is a groundbreaking
        branch of computer science focused on creating machines
        capable of simulating human cognitive functions.
        It powers everything from voice assistants and recommendation algorithms
        to medical diagnostics and autonomous systems, utilizing data and machine learning
        to constantly improve its own accuracy and efficiency."""

tokens = text.split()

print(tokens)
# Out:
# ['Artificial', 'Intelligence', '(AI)', 'is', 'a', 'groundbreaking', 'branch', 'of', 'computer', 'science', 'focused', 'on', 'creating', 'machines', 'capable', 'of', 'simulating', 'human', 'cognitive', 'functions.', 'It', 'powers', 'everything', 'from', 'voice', 'assistants', 'and', 'recommendation', 'algorithms', 'to', 'medical', 'diagnostics', 'and', 'autonomous', 'systems,', 'utilizing', 'data', 'and', 'machine', 'learning', 'to', 'constantly', 'improve', 'its', 'own', 'accuracy', 'and', 'efficiency.']

# %%
import nltk

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\biren\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\biren\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\biren\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\biren\AppData\Roaming\nltk_data...
# True

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

doc = [
    'the cat sat on the mat',
    'the dog played in the park',
    'cats and dogs are great pets'
]

tfidf = TfidfVectorizer()
result = tfidf.fit_transform(doc)

print(tfidf.get_feature_names_out())  
print(result)
# Out:
# ['and' 'are' 'cat' 'cats' 'dog' 'dogs' 'great' 'in' 'mat' 'on' 'park'
#  'pets' 'played' 'sat' 'the']
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 16 stored elements and shape (3, 15)>
#   Coords	Values
#   (0, 14)	0.6053485081062917
#   (0, 2)	0.3979802707840827
#   (0, 13)	0.3979802707840827
#   (0, 9)	0.3979802707840827
#   (0, 8)	0.3979802707840827
#   (1, 14)	0.6053485081062917
#   (1, 4)	0.3979802707840827
#   (1, 12)	0.3979802707840827
#   (1, 7)	0.3979802707840827
#   (1, 10)	0.3979802707840827
#   (2, 3)	0.4082482904638631
#   (2, 0)	0.4082482904638631
#   (2, 5)	0.4082482904638631
#   (2, 1)	0.4082482904638631
#   (2, 6)	0.4082482904638631
#   (2, 11)	0.4082482904638631

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\biren\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\biren\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
import nltk



from nltk.tokenize import word_tokenize

text = """Artificial Intelligence (AI) is a groundbreaking
branch of computer science focused on creating machines
capable of simulating human cognitive functions.
It powers everything from voice assistants and recommendation algorithms"""

words = word_tokenize(text)

print(words)
# Out:
# ['Artificial', 'Intelligence', '(', 'AI', ')', 'is', 'a', 'groundbreaking', 'branch', 'of', 'computer', 'science', 'focused', 'on', 'creating', 'machines', 'capable', 'of', 'simulating', 'human', 'cognitive', 'functions', '.', 'It', 'powers', 'everything', 'from', 'voice', 'assistants', 'and', 'recommendation', 'algorithms']

# %%
import nltk

from nltk.tokenize import sent_tokenize

text = """Artificial Intelligence (AI) is a groundbreaking
branch of computer science focused on creating machines.
It powers everything from voice assistants and recommendation algorithms.
NLP is a part of AI."""

sentences = sent_tokenize(text)

print(sentences)
# Out:
# ['Artificial Intelligence (AI) is a groundbreaking\nbranch of computer science focused on creating machines.', 'It powers everything from voice assistants and recommendation algorithms.', 'NLP is a part of AI.']

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\biren\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer(language="english")
word = "civilization"
stemmed_word = stemmer.stem(word)
print(stemmed_word)
# Out:
# civil

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\biren\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')

text = """I have a fever. I have a headache. My throat is sore.
I have a persistent cough. I feel dizzy today.
I have stomach pain. I am experiencing chest pain.
I am allergic to penicillin. I feel nauseous after eating.
I have a toothache. My vision is blurry.
I have back pain. I have lost my appetite."""

# Set of stopwords
stop_words = set(stopwords.words('english'))

# Tokenization
word_tokens = word_tokenize(text)

# Remove stopwords
filtered_sentence = []

for w in word_tokens:
    if w.lower() not in stop_words:   # lower() is important
        filtered_sentence.append(w)

print(filtered_sentence)
# Out:
# ['fever', '.', 'headache', '.', 'throat', 'sore', '.', 'persistent', 'cough', '.', 'feel', 'dizzy', 'today', '.', 'stomach', 'pain', '.', 'experiencing', 'chest', 'pain', '.', 'allergic', 'penicillin', '.', 'feel', 'nauseous', 'eating', '.', 'toothache', '.', 'vision', 'blurry', '.', 'back', 'pain', '.', 'lost', 'appetite', '.']
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\biren\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\biren\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\biren\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

words = ["running", "played", "studies", "cars", "children"]

for word in words:
    print(word, "->", lemmatizer.lemmatize(word))
# Out:
# running -> running
# played -> played
# studies -> study
# cars -> car
# children -> child

# %%
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

porter = PorterStemmer()
lemmatizer = WordNetLemmatizer()

print(f"better\nStemming: {porter.stem('better')}\nLemmatization: {lemmatizer.lemmatize('better', pos='a')}")
# Out:
# better
# Stemming: better
# Lemmatization: good
